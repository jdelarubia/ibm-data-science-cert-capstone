# %% [markdown]
# # 7. Folium
#
# - Pin all launch sites on a map
# - Pin all success/failed launches for each site on the map
# - Find distances from launch sites to their nearest coastline
#
# ## TOC
#
# - [Maps Setup](#maps-setup)
# - [Helpers](#helpers)
# - [Load data](#load-data)
# - [Data Wrangling](#data-wrangling)
# - [Launch sites](#plot-launch-sites)
# - [Success/failure rate](#plot-successfailure-rate)
# - [Distances to coastlines](#plot-distances-to-coastlines)

# %% [markdown]
# ## Imports

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster
from folium.features import DivIcon
from pathlib import Path

from math import sin, cos, sqrt, atan2, radians

import helpers as hlp

# %% [markdown]
# ## Maps setup

# %%
INPUT_FILE = hlp.DATA_DIR / Path("spacex_launch_geo.csv")

# Folium settings
MAP_WIDTH = 720
MAP_HEIGHT = 400
MAP_LOCATION = [30, -99]
MAP_ZOOM = 4

TITLE_COLOR = "#2277ff"
TITLE_CSS = f"""
display: flex;
justify-content: center;
width: 100%; 
background-color: {TITLE_COLOR}; 
color: white;
line-height: 2em; 
font-weight: bold;
"""

# %% [markdown]
# ## Helpers

# %%
def calculate_distance(coords_1: list[float], coords_2: list[float]):
    """Return the distance between 2 pairs of coordinates"""
    # approximate radius of earth in km
    R = 6373.0

    lat1, lon1 = coords_1
    lat2, lon2 = coords_2
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv(INPUT_FILE, encoding="utf-8", header=0, index_col=False)

# normalize column names
df.columns = [hlp.normalize_column_name(col) for col in df.columns]
df.head()
# Out:
#    flight_number        date  time_utc booster_version  launch_site  \
# 0              1  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08   0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01  15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              payload  payload_mass_kg  \
# 0               Dragon Spacecraft Qualification Unit              0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...              0.0
# 2                             Dragon demo flight C2+            525.0
# 3                                       SpaceX CRS-1            500.0
# 4                                       SpaceX CRS-2            677.0
#
#        orbit         customer        landing_outcome  class        lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %%
df["booster_version"].value_counts()
# Out:
# booster_version
# F9 v1.1           5
# F9 v1.0  B0003    1
# F9 v1.0  B0005    1
# F9 v1.0  B0004    1
# F9 v1.0  B0006    1
# F9 v1.0  B0007    1
# F9 v1.1 B1011     1
# F9 v1.1 B1010     1
# F9 v1.1 B1012     1
# F9 v1.1 B1013     1
# F9 v1.1 B1014     1
# F9 v1.1 B1015     1
# F9 v1.1 B1016     1
# F9 v1.1 B1018     1
# F9 FT B1019       1
# F9 FT B1020       1
# F9 FT B1021.1     1
# F9 FT B1022       1
# F9 FT B1023.1     1
# F9 FT B1024       1
# F9 FT B1025.1     1
# F9 FT B1026       1
# F9 v1.1  B1003    1
# F9 v1.1 B1017     1
# F9 FT B1029.1     1
# F9 FT B1036.1     1
# F9 FT B1038.1     1
# F9 B4 B1041.1     1
# F9 FT  B1036.2    1
# F9 FT  B1038.2    1
# F9 B4  B1041.2    1
# F9 B4  B1043.2    1
# F9 FT B1031.1     1
# F9 FT B1030       1
# F9 FT  B1021.2    1
# F9 FT B1032.1     1
# F9 FT B1034       1
# F9 FT B1035.1     1
# F9 FT  B1029.2    1
# F9 FT B1037       1
# F9 B4 B1039.1     1
# F9 B4 B1040.1     1
# F9 FT  B1031.2    1
# F9 B4 B1042.1     1
# F9 B5  B1046.1    1
# F9 FT  B1035.2    1
# F9 B4 B1043.1     1
# F9 FT  B1032.2    1
# F9 B4 B1044       1
# F9 B4  B1039.2    1
# F9 B4 B1045.1     1
# F9 B4  B1040.2    1
# Name: count, dtype: int64

# %% [markdown]
# ## Data Wrangling

# %%
coastline_coords = {
    "CCAFS LC-40": (28.5623, -80.56789),
    "CCAFS SLC-40": (28.5631, -80.56789),
    "KSC LC-39A": (28.57269, -80.60626),
    "VAFB SLC-4E": (34.633, -120.62735),
}

df = df.rename(columns={"long": "lon"})
# add columns for later use
df["marker_color"] = df["class"].apply(
    lambda outcome: "green" if outcome == 1 else "red"
)

for location in coastline_coords:
    lat, lon = coastline_coords[location]
    df.loc[df["launch_site"] == location, "coastline_lat"] = lat
    df.loc[df["launch_site"] == location, "coastline_lon"] = lon

df["coastline_distance"] = df.apply(
    lambda row: calculate_distance(
        [row["lat"], row["lon"]], [row["coastline_lat"], row["coastline_lon"]]
    ),
    axis=1,
)

df.head()
# Out:
#    flight_number        date  time_utc booster_version  launch_site  \
# 0              1  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08   0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01  15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              payload  payload_mass_kg  \
# 0               Dragon Spacecraft Qualification Unit              0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...              0.0
# 2                             Dragon demo flight C2+            525.0
# 3                                       SpaceX CRS-1            500.0
# 4                                       SpaceX CRS-2            677.0
#
#        orbit         customer        landing_outcome  class        lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#          lon marker_color  coastline_lat  coastline_lon  coastline_distance
# 0 -80.577356          red        28.5623      -80.56789            0.924808
# 1 -80.577356          red        28.5623      -80.56789            0.924808
# 2 -80.577356          red        28.5623      -80.56789            0.924808
# 3 -80.577356          red        28.5623      -80.56789            0.924808
# 4 -80.577356          red        28.5623      -80.56789            0.924808

# %%
df_temp = df[["launch_site", "lat", "lon", "class", "marker_color"]]
df_locations = df_temp.groupby(["launch_site"], as_index=False)[
    ["launch_site", "lon", "lat"]
]
df_locations = df_locations.value_counts()[["launch_site", "lat", "lon"]]

# %%
df_locations
# Out:
#     launch_site        lat         lon
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# ## Misc map functions

# %%
def build_map() -> folium.Map:
    return folium.Map(
        location=MAP_LOCATION,
        # tiles="OpenStreetMap",
        tiles="Cartodb Positron",
        zoom_start=MAP_ZOOM,
        zoom_control=True,
    )


def build_title(title: str) -> folium.Element:
    return folium.Element(
        f"""<h3 style='{TITLE_CSS}
        '>{title}</h3>"""
    )

# %% [markdown]
# ## Plot Launch sites

# %%
def graph_launch_sites(locations: pd.DataFrame):
    title = build_title("Falcon 9 launch locations")
    fig = folium.Figure(width=MAP_WIDTH, height=MAP_HEIGHT)
    site_map = build_map()

    for _, row in locations.iterrows():
        site_name, lat, long = row.values
        html = f'<div style="font-size:18;color:#000;"><b>{site_name}</b></div>'
        coords = [lat, long]
        circle = folium.Circle(coords, radius=1000, color="red", fill=True)
        icon = folium.Icon(
            color="red",
            icon="rocket",
            prefix="fa",
            icon_size=(35, 45),
            icon_anchor=(20, 50),
            shadow_size=0,
        )
        marker = folium.Marker(
            location=coords,
            popup=site_name,
            icon=DivIcon(icon_size=(35, 45), icon_anchor=(10, -10), html=html),
        )
        marker.add_child(icon)
        site_map.add_child(marker)
        site_map.add_child(circle)

    fig.get_root().html.add_child(title)
    fig.add_child(site_map)
    return fig


site_map = graph_launch_sites(df_locations)
site_map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2334605b2029c5100baf2fd6425b1a23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;
# display: flex;
# justify-content: center;
# width: 100%;
# background-color: #2277ff;
# color: white;
# line-height: 2em;
# font-weight: bold;
#
#         &#x27;&gt;Falcon 9 launch locations&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2334605b2029c5100baf2fd6425b1a23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2334605b2029c5100baf2fd6425b1a23 = L.map(
#                 &quot;map_2334605b2029c5100baf2fd6425b1a23&quot;,
#                 {
#                     center: [30.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9066966362a96da06dbb10cb32115c99 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9066966362a96da06dbb10cb32115c99.addTo(map_2334605b2029c5100baf2fd6425b1a23);
#
#
#             var marker_81b39452fa53c26dd449eb868a583304 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_2334605b2029c5100baf2fd6425b1a23);
#
#
#             var div_icon_acaa5bbfa3b31d92f407fe37c3a1a5ef = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:18;color:#000;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [35, 45],
#   &quot;iconAnchor&quot;: [10, -10],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_9c744e80c21b4d15bad7336069266629 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_931f6494f071b6492441ad2b59e8e377 = $(`&lt;div id=&quot;html_931f6494f071b6492441ad2b59e8e377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_9c744e80c21b4d15bad7336069266629.setContent(html_931f6494f071b6492441ad2b59e8e377);
#
#
#
#         marker_81b39452fa53c26dd449eb868a583304.bindPopup(popup_9c744e80c21b4d15bad7336069266629)
#         ;
#
#
#
#
#             var icon_bd24c7ca3b65ed82990184892fb1f777 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
#   &quot;iconSize&quot;: [35, 45],
#   &quot;iconAnchor&quot;: [20, 50],
#   &quot;shadowSize&quot;: 0,
# }
#             );
#
#
#                 marker_81b39452fa53c26dd449eb868a583304.setIcon(icon_bd24c7ca3b65ed82990184892fb1f777);
#
#
#             var circle_9a99c36f02c6a74c75ab3da539e5abd2 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2334605b2029c5100baf2fd6425b1a23);
#
#
#             var marker_5ab18b16b466053c9432ba81708bdb94 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_2334605b2029c5100baf2fd6425b1a23);
#
#
#             var div_icon_82449d24587bc56be25c1378b0251db2 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:18;color:#000;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [35, 45],
#   &quot;iconAnchor&quot;: [10, -10],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#         var popup_55e92d46603b75d1c362fbcd543e9c73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a591eac7ba7119db9628e78384bd72c4 = $(`&lt;div id=&quot;html_a591eac7ba7119db9628e78384bd72c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_55e92d46603b75d1c362fbcd543e9c73.setContent(html_a591eac7ba7119db9628e78384bd72c4);
#
#
#
#         marker_5ab18b16b466053c9432ba81708bdb94.bindPopup(popup_55e92d46603b75d1c362fbcd543e9c73)
#         ;
#
#
#
#
#             var icon_9abab7c4160cab5cb4a63effd6196081 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quo

# %% [markdown]
# ## Success/Failure instances on each launch site

# %%
df.head(3)
# Out:
#    flight_number        date  time_utc booster_version  launch_site  \
# 0              1  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
#
#                                              payload  payload_mass_kg  \
# 0               Dragon Spacecraft Qualification Unit              0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...              0.0
# 2                             Dragon demo flight C2+            525.0
#
#        orbit         customer        landing_outcome  class        lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
#
#          lon marker_color  coastline_lat  coastline_lon  coastline_distance
# 0 -80.577356          red        28.5623      -80.56789            0.924808
# 1 -80.577356          red        28.5623      -80.56789            0.924808
# 2 -80.577356          red        28.5623      -80.56789            0.924808

# %% [markdown]
# ## PLot success/failure rate

# %%
def graph_success_failure_rate(df: pd.DataFrame):
    title = build_title("Success/Failure launches")
    fig = folium.Figure(width=MAP_WIDTH, height=MAP_HEIGHT)
    site_map = build_map()
    marker_cluster = MarkerCluster()

    for _, row in df.iterrows():
        site_name, lat, lon, classs, marker_color = row.values
        coords = [lat, lon]
        circle = folium.Circle(coords, radius=1000, color="red", fill=True)
        marker = folium.Marker(location=coords, popup=site_name)
        icon = folium.Icon(
            color="white", icon_color=marker_color, icon_anchor=(20, 50), shadow_size=0
        )
        marker.add_child(icon)
        marker_cluster.add_child(marker)
        site_map.add_child(circle)
        site_map.add_child(marker_cluster)

    fig.get_root().html.add_child(title)
    fig.add_child(site_map)
    return fig


site_map = graph_success_failure_rate(
    df[["launch_site", "lat", "lon", "class", "marker_color"]]
)
site_map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a3eba36b8fd2cecbf3a87af72b75ec9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;
# display: flex;
# justify-content: center;
# width: 100%;
# background-color: #2277ff;
# color: white;
# line-height: 2em;
# font-weight: bold;
#
#         &#x27;&gt;Success/Failure launches&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a3eba36b8fd2cecbf3a87af72b75ec9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a3eba36b8fd2cecbf3a87af72b75ec9 = L.map(
#                 &quot;map_2a3eba36b8fd2cecbf3a87af72b75ec9&quot;,
#                 {
#                     center: [30.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c387d690684b9a84e0ccb2d286b58f7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c387d690684b9a84e0ccb2d286b58f7.addTo(map_2a3eba36b8fd2cecbf3a87af72b75ec9);
#
#
#             var circle_63b98f901e37f09942fa16d57db62686 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2a3eba36b8fd2cecbf3a87af72b75ec9);
#
#
#             var marker_cluster_7dd226759cb196fa48ce4c9fa14f951a = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_6f84baf07cccc4817858cdf9be3fd654 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_7dd226759cb196fa48ce4c9fa14f951a);
#
#
#         var popup_1177d3f73a5acaaf819fdc0963f5305d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3a08e3785690411e590d3ccd5ecb4ab = $(`&lt;div id=&quot;html_a3a08e3785690411e590d3ccd5ecb4ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_1177d3f73a5acaaf819fdc0963f5305d.setContent(html_a3a08e3785690411e590d3ccd5ecb4ab);
#
#
#
#         marker_6f84baf07cccc4817858cdf9be3fd654.bindPopup(popup_1177d3f73a5acaaf819fdc0963f5305d)
#         ;
#
#
#
#
#             var icon_a72f11bc0668d15d6aaafaade82df01a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
#   &quot;iconAnchor&quot;: [20, 50],
#   &quot;shadowSize&quot;: 0,
# }
#             );
#
#
#                 marker_6f84baf07cccc4817858cdf9be3fd654.setIcon(icon_a72f11bc0668d15d6aaafaade82df01a);
#
#
#             var marker_8dc0d3a5adae944c6832126b814fd6d2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_7dd226759cb196fa48ce4c9fa14f951a);
#
#
#         var popup_d2c8a1764455423245d2fb1c8219d4c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceef66ce1f545fa3c3ba92826b4b0d90 = $(`&lt;div id=&quot;html_ceef66ce1f545fa3c3ba92826b4b0d90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_d2c8a1764455423245d2fb1c8219d4c1.setContent(html_ceef66ce1f545fa3c3ba92826b4b0d90);
#
#
#
#         marker_8dc0d3a5adae944c6832126b814fd6d2.bindPopup(popup_d2c8a1764455423245d2fb1c8219d4c1)
#         ;
#
#
#
#
#             var icon_83319600a87d1596fef60568819b452c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
#   &quot;iconAnchor&quot;:

# %% [markdown]
# ## Plot distances to coastlines

# %%
df.head()
# Out:
#    flight_number        date  time_utc booster_version  launch_site  \
# 0              1  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08   0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01  15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              payload  payload_mass_kg  \
# 0               Dragon Spacecraft Qualification Unit              0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...              0.0
# 2                             Dragon demo flight C2+            525.0
# 3                                       SpaceX CRS-1            500.0
# 4                                       SpaceX CRS-2            677.0
#
#        orbit         customer        landing_outcome  class        lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#          lon marker_color  coastline_lat  coastline_lon  coastline_distance
# 0 -80.577356          red        28.5623      -80.56789            0.924808
# 1 -80.577356          red        28.5623      -80.56789            0.924808
# 2 -80.577356          red        28.5623      -80.56789            0.924808
# 3 -80.577356          red        28.5623      -80.56789            0.924808
# 4 -80.577356          red        28.5623      -80.56789            0.924808

# %%
def temp_print(df: pd.DataFrame):
    lines_coords = []
    i = 0
    for _, row in df.iterrows():
        site_name, lat, lon, coastline_lat, coastline_lon, coastline_distance = (
            row.values
        )
        site_coords = [lat, lon]
        coastline_coords = [coastline_lat, coastline_lon]
        lines_coords.append([site_coords, coastline_coords])
        # i += 1
        # if i >= 10:
        #     break
    print(lines_coords)


temp_print(
    df[
        [
            "launch_site",
            "lat",
            "lon",
            "coastline_lat",
            "coastline_lon",
            "coastline_distance",
        ]
    ]
)
# Out:
# [[[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[28.56230197, -80.57735648], [28.5623, -80.56789]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[34.63283416, -120.6107455], [34.633, -120.62735]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.57325457, -80.64689529], [28.57269, -80.60626]], [[28.56319718, -80.57682003], [28.5631, -80.56789]], [[28.56319718, -80.57682003], [28.5631, -80.56789]], [[28.56319718, -80.57682003], [28.5631, -80.56789]], [[28.56319718, -80.57682003], [28.5631, -80.56789]], [[28.56319718, -80.57682003], [28.5631, -80.56789]], [[28.56319718, -80.57682003], [28.5631, -80.56789]], [[28.56319718, -80.57682003], [28.5631, -80.56789]]]

# %%
def graph_distances_to_coastline(df: pd.DataFrame):
    title = build_title("Distances to coastline</h3>")
    fig = folium.Figure(width=MAP_WIDTH, height=MAP_HEIGHT)
    site_map = build_map()
    for _, row in df.iterrows():
        lines_coords = []
        site_name, lat, lon, coastline_lat, coastline_lon, coastline_distance = (
            row.values
        )
        site_coords = [lat, lon]
        coastline_coords = [coastline_lat, coastline_lon]
        lines_coords.append([site_coords, coastline_coords])
        circle = folium.Circle(site_coords, radius=10000, color=TITLE_COLOR, fill=False)
        coastline_line = folium.PolyLine(
            color="red",
            locations=lines_coords,
            smooth_factor=50,
            tooltip=f"{site_name} to coastline: {coastline_distance:.2f} km",
            weight=4,
        )
        # add distance
        icon = folium.DivIcon(
            html=f"<div style='font-size: 10pt; color: red'>{coastline_distance:.2f} Km.</div>",
            icon_size=(250, 40),
            icon_anchor=(20, 20),
        )
        marker = folium.Marker(location=coastline_coords)
        marker.add_child(icon)

        site_map.add_child(marker)
        site_map.add_child(circle)
        site_map.add_child(coastline_line)

    fig.get_root().html.add_child(title)
    fig.add_child(site_map)
    return fig


site_map = graph_distances_to_coastline(
    df[
        [
            "launch_site",
            "lat",
            "lon",
            "coastline_lat",
            "coastline_lon",
            "coastline_distance",
        ]
    ]
)
site_map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d97cecef691f83caac4931a4347ea032 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;
# display: flex;
# justify-content: center;
# width: 100%;
# background-color: #2277ff;
# color: white;
# line-height: 2em;
# font-weight: bold;
#
#         &#x27;&gt;Distances to coastline&lt;/h3&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d97cecef691f83caac4931a4347ea032&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d97cecef691f83caac4931a4347ea032 = L.map(
#                 &quot;map_d97cecef691f83caac4931a4347ea032&quot;,
#                 {
#                     center: [30.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f27261f7a91ec93cd1380bffc3be3fd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f27261f7a91ec93cd1380bffc3be3fd.addTo(map_d97cecef691f83caac4931a4347ea032);
#
#
#             var marker_1870a2a9efc3df9ca37332581196fe57 = L.marker(
#                 [28.5623, -80.56789],
#                 {
# }
#             ).addTo(map_d97cecef691f83caac4931a4347ea032);
#
#
#             var div_icon_20bdafe39eaae9a60659ccd82861788f = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027font-size: 10pt; color: red\u0027\u003e0.92 Km.\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 40],
#   &quot;iconAnchor&quot;: [20, 20],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_1870a2a9efc3df9ca37332581196fe57.setIcon(div_icon_20bdafe39eaae9a60659ccd82861788f);
#
#
#             var circle_1465ec4aed1a26fe7dad3aedffff1c2a = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2277ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2277ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d97cecef691f83caac4931a4347ea032);
#
#
#             var poly_line_bb39ce39e9d1b8ef1139f7ff44d9fcc9 = L.polyline(
#                 [[[28.56230197, -80.57735648], [28.5623, -80.56789]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_d97cecef691f83caac4931a4347ea032);
#
#
#             poly_line_bb39ce39e9d1b8ef1139f7ff44d9fcc9.bindTooltip(
#                 `&lt;div&gt;
#                      CCAFS LC-40 to coastline: 0.92 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_498b596780292fc890c97096947ac9c8 = L.marker(
#                 [28.5623, -80.56789],
#                 {
# }
#             ).addTo(map_d97cecef691f83caac4931a4347ea032);
#
#
#             var div_icon_4758696db05bac57075cd58746094da5 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027font-size: 10pt; color: red\u0027\u003e0.92 Km.\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 40],
#   &quot;iconAnchor&quot;: [20, 20],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_498b596780292fc890c97096947ac9c8.setIcon(div_icon_4758696db05bac57075cd58746094da5);
#
#
#             var circle_6ffa5e1fcc327e9619e17e5d47e8f098 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2277ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2277ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d97cecef691f83caac4931a4347ea032);
#
#
#             var poly_line_13f1ccb61749c4fd699d4028f874abd0 = L.polyline(
#                 [[[28.56230197, -80.57735648], [28.5623, -80.567
